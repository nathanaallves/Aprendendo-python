# %% [markdown]
# <a href="https://colab.research.google.com/github/nathanaallves/Aprendendo-python/blob/main/Aula_1_%7C_Elas%2BTech_Dados_Nathana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 1 | **Primeiros passos em Python**
#
# Hoje vamos:
# - Revisar alguns conceitos iniciais
# - Explorar dados reais usando Python
# - Aprender os primeiros comandos com **Pandas** e **Matplotlib**
# - Criar gráficos para responder perguntas
#
# ---

# %% [markdown]
# ## Conceitos básicos
#
# <img src="https://media0.giphy.com/media/v1.Y2lkPTc5MGI3NjExNHBwNDhvMDRoNDlvb2pkYnhtdGt4YXhqaWw1Y2Ixa200M2gxZDcxNiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/109fP7pua6Osgw/giphy.gif" width="300">

# %% [markdown]
# ### Tipos de dados
# `int`, `float`, `str`, `bool`

# %%
idade = 20
nome = "Nathana"
tem_acesso = True
nota = 8.5

# %%
print (type (idade), type (nome), type(tem_acesso), type(nota))
# Out:
# <class 'int'> <class 'str'> <class 'bool'> <class 'float'>

# %%
idade = "40"
type(idade)
# Out:
# str

# %%
idade_int = int(idade)
type(idade_int)
# Out:
# int

# %%
valor = '10.5'
valor_float = float(valor) #convertendo de srt para float
valor_int = int(float (valor))

print(f'Exemplo float: {type(valor_float)} : {valor_float}')
print(f'Exemplo int: {type(valor_int)} :{valor_int}')
# Out:
# Exemplo float: <class 'float'> : 10.5
# Exemplo int: <class 'int'> :10

# %% [markdown]
# ### Listas

# %%
nome = ["Nathana", "José", "Matheus", "Larissa","Ronaldo","Leticia","Carina"]
print (type(nome))
# Out:
# <class 'list'>

# %%
print(nome[0]) #primeiro elemento da lista
print(nome[-1]) #ultimo elemento da lista
print(nome[2:5])
# Out:
# Nathana
# Carina
# ['Matheus', 'Larissa', 'Ronaldo']

# %%
nome.append("Maria") #adicionando mais um item na lista"
print(nome)
# Out:
# ['Nathana', 'José', 'Matheus', 'Larissa', 'Ronaldo', 'Leticia', 'Carina', 'Maria']

# %%
nome.remove("Nathana") #removendo mais um item na lista"
print(nome)
# Out:
# ['José', 'Matheus', 'Larissa', 'Ronaldo', 'Leticia', 'Carina', 'Maria']

# %%
print ("Nathana" in nome) #verifica se existe esse nome na lista
# Out:
# False

# %% [markdown]
# ### Estruturas de decisão
# `if`, `elif` e `else`

# %%
nota = 8

if nota >=7:
  print('Aprovada')
else:
  print('Reprovada')
# Out:
# Aprovada

# %%
nota = 5

if nota >=9:
  print('Excelente')
elif nota >=7:
  print('Bom desempenho')
elif nota >=5:
  print('Em recuperação')
else:
  print('Reprovada')
# Out:
# Em recuperação

# %% [markdown]
# ### Loops
# `for` e `while`

# %%
for i in range(3):
  print(f'Rodando o loop {i + 1}')
# Out:
# Rodando o loop 1
# Rodando o loop 2
# Rodando o loop 3

# %%
contador = 1

while contador <= 10:
  print(f'Contando... {contador}')
  contador += 1 #incrementando
# Out:
# Contando... 1
# Contando... 2
# Contando... 3
# Contando... 4
# Contando... 5
# Contando... 6
# Contando... 7
# Contando... 8
# Contando... 9
# Contando... 10

# %% [markdown]
# ## 🎧 Explorando dados do Spotify
#
# <img src="https://media0.giphy.com/media/v1.Y2lkPTc5MGI3NjExaWJtNjFxcmJ6YXk4eDAyMXVyc3o3cGF2NGF6czhkaXl1anAzNzU0ciZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/bgDd8eRNi6NK8/giphy.gif" width="300">
#
#
# Aqui, vamos explorar dados extraídos da conta de um usuário do Spotify para entender um pouco do seu perfil e gosto musical. Trabalharemos com dois datasets:
# 1. **playlists_tracks**: contém a listagem de todas as suas playlists públicas e as músicas contidas nelas
# 2. **genres_artists**: contém a listagem de artistas presentes nas playlists e seus gêneros

# %% [markdown]
# ### Leitura e visão geral dos dados

# %%
#pandas para leitura de dados
import pandas as pd #pd apelido

playlists_tracks = pd.read_csv('./playlists_tracks')
genres_artists = pd.read_csv('./genres_artists')

# %%
playlists_tracks.shape #formato da playlist
# Out:
# (8661, 10)

# %%
genres_artists.shape
# Out:
# (934, 3)

# %%
playlists_tracks.head(3)
# Out:
#    Unnamed: 0             playlist_id           playlist_name  \
# 0           0  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
# 1           1  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
# 2           2  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
#
#                  track_id                       track_name  \
# 0  59WN2psjkt1tyaxjspN8fp              Killing In The Name
# 1  2DlHlPMa4M17kufBvI2lEN                       Chop Suey!
# 2  3DwQ7AH3xGD9h65ezslm6q  Enter Sandman - Remastered 2021
#
#                artist_names  \
# 0  Rage Against The Machine
# 1          System Of A Down
# 2                 Metallica
#
#                                           album_name album_release_date  \
# 0  Rage Against The Machine - XX (20th Anniversar...               1992
# 1                                           Toxicity         2001-09-04
# 2              Metallica (Remastered Deluxe Box Set)         2021-09-10
#
#    popularity  duration_ms
# 0          79       313573
# 1          85       210240
# 2          83       331560

# %%
import pandas as pd #pd apelido
playlists_tracks = pd.read_csv('./playlists_tracks')

playlists_tracks["playlist_name"].value_counts()
# Out:
# playlist_name
# Caminhando sem padrão nenhum                  311
# Rockzim pra cantar junto                      300
# cantando feat. rebolando                      274
# tudo misturado curtindo uma chuva             261
# Radio em '00                                  241
#                                              ...
# indie mtv 6h em 2008                           18
# Nunca canso de ouvir                           16
# Instrumental                                   16
# Músicas de ouvir 2x pra aproveitar direito     16
# Euro trip #3                                    6
# Name: count, Length: 89, dtype: int64

# %%
playlists_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8661 entries, 0 to 8660
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          8661 non-null   int64
#  1   playlist_id         8661 non-null   object
#  2   playlist_name       8661 non-null   object
#  3   track_id            8661 non-null   object
#  4   track_name          8659 non-null   object
#  5   artist_names        8659 non-null   object
#  6   album_name          8659 non-null   object
#  7   album_release_date  8661 non-null   object
#  8   popularity          8661 non-null   int64
#  9   duration_ms         8661 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 676.8+ KB

# %%
genres_artists.head(3)
# Out:
#    Unnamed: 0               artist_name  \
# 0           0  Rage Against The Machine
# 1           1          System Of A Down
# 2           2                 Metallica
#
#                                               genres
# 0   rap metal, rap rock, alternative metal, nu metal
# 1  nu metal, metal, alternative metal, rap metal,...
# 2  metal, thrash metal, rock, heavy metal, hard rock

# %%
genres_artists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   934 non-null    int64
#  1   artist_name  934 non-null    object
#  2   genres       660 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 22.0+ KB

# %% [markdown]
# ### Limpeza e transformações
#
# Antes de analisarmos as playlists e os gêneros, vamos preparar nossos dados:
# 1. Extrair apenas o **ano** da data de lançamento dos álbuns
# 2. Remover músicas com **nome ausente**
# 3. Transformar a tabela de gêneros para que cada **gênero tenha uma linha própria**

# %% [markdown]
# 1. Extrair o ano

# %%
#adicionando uma coluna nova
playlists_tracks['album_release_year'] = pd.to_datetime(playlists_tracks['album_release_date_ajustado'], errors="coerce")

# %%
playlists_tracks.columns
# Out:
# Index(['Unnamed: 0', 'playlist_id', 'playlist_name', 'track_id', 'track_name',
#        'artist_names', 'album_name', 'album_release_date', 'popularity',
#        'duration_ms', 'album_release_date_ajustado', 'album_release_year'],
#       dtype='object')

# %%
playlists_tracks['album_release_date'] = playlists_tracks["album_release_date_ajustado"].dt.year
playlists_tracks.head(3)
# Out:
#    Unnamed: 0             playlist_id           playlist_name  \
# 0           0  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
# 1           1  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
# 2           2  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
#
#                  track_id                       track_name  \
# 0  59WN2psjkt1tyaxjspN8fp              Killing In The Name
# 1  2DlHlPMa4M17kufBvI2lEN                       Chop Suey!
# 2  3DwQ7AH3xGD9h65ezslm6q  Enter Sandman - Remastered 2021
#
#                artist_names  \
# 0  Rage Against The Machine
# 1          System Of A Down
# 2                 Metallica
#
#                                           album_name  album_release_date  \
# 0  Rage Against The Machine - XX (20th Anniversar...              1992.0
# 1                                           Toxicity                 NaN
# 2              Metallica (Remastered Deluxe Box Set)                 NaN
#
#    popularity  duration_ms album_release_date_ajustado album_release_year
# 0          79       313573                  1992-01-01         1992-01-01
# 1          85       210240                         NaT                NaT
# 2          83       331560                         NaT                NaT

# %% [markdown]
# 2. Excluir linhas com track_name ausente

# %%
playlists_tracks.shape
# Out:
# (8661, 12)

# %%
#excluindo as linhas vazias
playlists_tracks_clean = playlists_tracks.dropna(subset=['track_name'])
playlists_tracks_clean.shape
# Out:
# (8659, 12)

# %% [markdown]
# 3. Explodir os gêneros (1 linha por artista e gênero)

# %%
genres_artists = pd.read_csv('./genres_artists')
genres_artists.head(5)
# Out:
#    Unnamed: 0               artist_name  \
# 0           0  Rage Against The Machine
# 1           1          System Of A Down
# 2           2                 Metallica
# 3           3             Dead Kennedys
# 4           4                 The Hives
#
#                                               genres
# 0   rap metal, rap rock, alternative metal, nu metal
# 1  nu metal, metal, alternative metal, rap metal,...
# 2  metal, thrash metal, rock, heavy metal, hard rock
# 3        punk, hardcore punk, skate punk, proto-punk
# 4                                        garage rock

# %%
'punk, hardcore punk, skate punk, proto-punk'.split(',')
# Out:
# ['punk', ' hardcore punk', ' skate punk', ' proto-punk']

# %%
genres_artists['lista_generos'] = genres_artists['genres'].fillna('').str.split(',')
genres_artists.head(5)
# Out:
#    Unnamed: 0               artist_name  \
# 0           0  Rage Against The Machine
# 1           1          System Of A Down
# 2           2                 Metallica
# 3           3             Dead Kennedys
# 4           4                 The Hives
#
#                                               genres  \
# 0   rap metal, rap rock, alternative metal, nu metal
# 1  nu metal, metal, alternative metal, rap metal,...
# 2  metal, thrash metal, rock, heavy metal, hard rock
# 3        punk, hardcore punk, skate punk, proto-punk
# 4                                        garage rock
#
#                                        lista_generos
# 0  [rap metal,  rap rock,  alternative metal,  nu...
# 1  [nu metal,  metal,  alternative metal,  rap me...
# 2  [metal,  thrash metal,  rock,  heavy metal,  h...
# 3   [punk,  hardcore punk,  skate punk,  proto-punk]
# 4                                      [garage rock]

# %%
genero_explodido = genres_artists.explode('lista_generos')
genero_explodido.head(5)
# Out:
#    Unnamed: 0               artist_name  \
# 0           0  Rage Against The Machine
# 0           0  Rage Against The Machine
# 0           0  Rage Against The Machine
# 0           0  Rage Against The Machine
# 1           1          System Of A Down
#
#                                               genres       lista_generos
# 0   rap metal, rap rock, alternative metal, nu metal           rap metal
# 0   rap metal, rap rock, alternative metal, nu metal            rap rock
# 0   rap metal, rap rock, alternative metal, nu metal   alternative metal
# 0   rap metal, rap rock, alternative metal, nu metal            nu metal
# 1  nu metal, metal, alternative metal, rap metal,...            nu metal

# %%
# genero_explodido = genero_explodido.drop(columns=['genres', 'Unnamed: 0'])
genero_explodido.drop(columns=['genres', 'Unnamed: 0'], inplace=True)
genero_explodido.shape
# Out:
# (1789, 2)

# %%
genero_explodido[genero_explodido['lista_generos'] == '']
# Out:
#             artist_name lista_generos
# 14                 NAPA
# 16            Balthazar
# 18                Lorde
# 19           Lola Young
# 20              Beyoncé
# ..                  ...           ...
# 910  Family of the Year
# 912             McEnroe
# 913   Lighthouse Family
# 917  Unknown Artist LTG
# 926     Mélanie Laurent
#
# [274 rows x 2 columns]

# %%
genero_explodido_limpo = genero_explodido[genero_explodido['lista_generos'] != '']
genero_explodido_limpo.shape
# Out:
# (1515, 2)

# %%
' rap rock' == 'rap rock'
# Out:
# False

# %%
'        rap rock    '.strip()
# Out:
# 'rap rock'

# %%
genero_explodido_limpo['lista_generos'].nunique()
# Out:
# 333

# %%
genero_explodido_limpo['lista_generos'] = genero_explodido_limpo['lista_generos'].str.strip()
# Out:
# /tmp/ipython-input-2714457631.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genero_explodido_limpo['lista_generos'] = genero_explodido_limpo['lista_generos'].str.strip()

# %%
genero_explodido_limpo['lista_generos'].nunique()
# Out:
# 224

# %%
'punk, hardcore punk, skate punk, proto-punk'.split(',')
# Out:
# ['punk', ' hardcore punk', ' skate punk', ' proto-punk']

# %%
','.join(['punk', ' hardcore punk', ' skate punk', ' proto-punk'])
# Out:
# 'punk, hardcore punk, skate punk, proto-punk'

# %% [markdown]
# ## Visualização com Matplotlib
#
# <img src="https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExazlycDZvOXZzbXN1Z2djZzZ3cnU0M3FkeXdnbzJxMGdjbmpsZGVseSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/iRIf7MAdvOIbdxK4rR/giphy.gif" width="300">
#
# Agora que os dados estão limpos, vamos responder algumas perguntas com gráficos.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Quais playlists têm mais músicas?

# %%
playlists_counts = playlists_tracks_clean['playlist_name'].value_counts().head(10)
playlists_counts
# Out:
# playlist_name
# Caminhando sem padrão nenhum         311
# Rockzim pra cantar junto             300
# cantando feat. rebolando             274
# tudo misturado curtindo uma chuva    261
# Radio em '00                         241
# VOLTA JUVENTUDE                      239
# Black power                          231
# jovem indie                          219
# Top indie                            215
# Só ~good vibe~                       210
# Name: count, dtype: int64

# %%
playlists_counts.plot(kind="barh", figsize=(8,5)) #grafico em barra, com o tamanho descrito
plt.title('Top 10 playlists com mais músicas')
plt.xlabel("Quantidade de músicas")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### Como evolui a quantidade de músicas lançadas por ano nas playlists?

# %%
plt.style.use('seaborn-v0_8') #melhorando o estilo do grafico

# %%
songs_per_year = (
    playlists_tracks_clean ['album_release_date']
    .value_counts()
    .sort_index()
)
songs_per_year
# Out:
# album_release_date
# 1958.0     1
# 1960.0     4
# 1964.0     3
# 1966.0     1
# 1967.0     7
# 1968.0    14
# 1969.0     5
# 1970.0    25
# 1971.0     5
# 1972.0    22
# 1973.0    15
# 1974.0     7
# 1975.0    19
# 1976.0     6
# 1977.0     9
# 1978.0     8
# 1979.0    10
# 1980.0     5
# 1981.0     5
# 1982.0    12
# 1983.0     2
# 1984.0    11
# 1985.0     5
# 1986.0     3
# 1987.0     2
# 1988.0     8
# 1989.0     2
# 1990.0     1
# 1991.0     3
# 1992.0    18
# 1993.0     2
# 1994.0     2
# 1995.0    34
# 1996.0     5
# 1997.0     5
# 1999.0    21
# 2000.0    25
# 2001.0    29
# 2002.0    27
# 2003.0    14
# 2004.0    42
# 2005.0     3
# 2006.0    13
# 2007.0    18
# 2008.0    11
# 2009.0    36
# 2010.0    12
# 2011.0    20
# 2012.0     3
# 2013.0    41
# 2015.0     1
# 2016.0    10
# 2019.0    17
# Name: count, dtype: int64

# %% [markdown]
# ### Quais são os artistas com maior popularidade média?

# %%
avg_popularity_per_artist = playlists_tracks_clean.groupby('artist_names')['popularity'].mean().sort_values(ascending=False)
display(avg_popularity_per_artist.head())
# Out:
# artist_names
# The Neighbourhood        91.0
# Gorillaz, De La Soul     90.0
# Fleetwood Mac            89.0
# The Weeknd, Daft Punk    89.0
# Kendrick Lamar, SZA      89.0
# Name: popularity, dtype: float64

# %% [markdown]
# ### Quais são os artistas mais frequentes nas playlists?

# %%
artist_counts = playlists_tracks_clean['artist_names'].value_counts()
display(artist_counts.head())
# Out:
# artist_names
# Oasis             160
# Olivia Dean       159
# Jungle            143
# Arctic Monkeys    138
# Beyoncé           131
# Name: count, dtype: int64

# %% [markdown]
# ### Quais gêneros são mais frequentes entre os artistas das playlists?

# %%
genre_counts = df_consolidado['lista_generos'].value_counts()
display(genre_counts.head())

# %% [markdown]
# ### Qual é a duração média das músicas por playlist?

# %%
avg_duration_per_playlist = playlists_tracks_clean.groupby('playlist_name')['duration_ms'].mean()
display(avg_duration_per_playlist.head())
# Out:
# playlist_name
# +55                  226099.039735
# Andando relaxando    233643.430769
# Antigo br bem bom    213012.117647
# Aquela jantinha      231714.047619
# Bebendo na sala      240190.526316
# Name: duration_ms, dtype: float64

# %% [markdown]
# ### Exercício: Existe relação entre o ano de lançamento e a duração média das músicas?

# %%
avg_duration_per_year.plot(kind='line', marker="o", figsize=(12, 6))
plt.title('Average Song Duration Over Time', loc='left')
plt.xlabel("Release Year")
plt.ylabel("Average Duration (ms)")
plt.grid(True, linestyle= '--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Exercício: Quão diversa em gêneros é cada playlist?
# Em outras palavras, quais playlists têm mais gêneros distintos entre os artistas que aparecem nelas?

# %%
playlists_tracks.columns
# Out:
# Index(['Unnamed: 0', 'playlist_id', 'playlist_name', 'track_id', 'track_name',
#        'artist_names', 'album_name', 'album_release_date', 'popularity',
#        'duration_ms', 'album_release_date_ajustado', 'album_release_year'],
#       dtype='object')

# %%
genero_explodido_limpo.columns
# Out:
# Index(['artist_name', 'lista_generos'], dtype='object')

# %%
df_consolidado = playlists_tracks.merge(
    genero_explodido_limpo,
    left_on = 'artist_names',
    right_on = 'artist_name',
    how = 'left' # traz todas as playlists independete se tem genero associado ou não
)

# %%
df_consolidado.head(5)
# Out:
#    Unnamed: 0             playlist_id           playlist_name  \
# 0           0  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
# 1           0  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
# 2           0  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
# 3           0  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
# 4           1  2VhIiQbHHMKRPEeCukaeZt  Climinha de presencial
#
#                  track_id           track_name              artist_names  \
# 0  59WN2psjkt1tyaxjspN8fp  Killing In The Name  Rage Against The Machine
# 1  59WN2psjkt1tyaxjspN8fp  Killing In The Name  Rage Against The Machine
# 2  59WN2psjkt1tyaxjspN8fp  Killing In The Name  Rage Against The Machine
# 3  59WN2psjkt1tyaxjspN8fp  Killing In The Name  Rage Against The Machine
# 4  2DlHlPMa4M17kufBvI2lEN           Chop Suey!          System Of A Down
#
#                                           album_name  album_release_date  \
# 0  Rage Against The Machine - XX (20th Anniversar...              1992.0
# 1  Rage Against The Machine - XX (20th Anniversar...              1992.0
# 2  Rage Against The Machine - XX (20th Anniversar...              1992.0
# 3  Rage Against The Machine - XX (20th Anniversar...              1992.0
# 4                                           Toxicity                 NaN
#
#    popularity  duration_ms album_release_date_ajustado album_release_year  \
# 0          79       313573                  1992-01-01         1992-01-01
# 1          79       313573                  1992-01-01         1992-01-01
# 2          79       313573                  1992-01-01         1992-01-01
# 3          79       313573                  1992-01-01         1992-01-01
# 4          85       210240                         NaT                NaT
#
#                 artist_name      lista_generos
# 0  Rage Against The Machine          rap metal
# 1  Rage Against The Machine           rap rock
# 2  Rage Against The Machine  alternative metal
# 3  Rage Against The Machine           nu metal
# 4          System Of A Down           nu metal

# %% [markdown]
# ---
#
# <img src="https://media2.giphy.com/media/v1.Y2lkPTc5MGI3NjExMmxwajYzcWh3NmRhNjN0N2plMDV5ZGdrcHQ0ZnlqeW55bTd6NjdnYSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/lD76yTC5zxZPG/giphy.gif" width="300">
